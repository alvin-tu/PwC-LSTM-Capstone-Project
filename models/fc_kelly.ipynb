# %%
import pandas as pd
import numpy as np
import os
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
from torch.utils.data import Dataset
from torchsummary import summary

from time import time 

import tqdm

import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
# Out:
# /home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/google/auth/crypt/_cryptography_rsa.py:22: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography. The next release of cryptography (40.0) will be the last to support Python 3.6.
#   import cryptography.exceptions

# %%
class IsaacDS(Dataset):
    def __init__(self, split, features, data_dir):
        self.split = split
        self.features = features
        self.data_dir = data_dir
        self.df = self.getdf()
      

    def getdf(self):
        path = os.path.join(self.data_dir, f'isaac_{self.split}.csv')
        df = pd.read_csv(path)
        df = df[self.features]
        
        return df
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        X = self.df.drop(columns=['value']).iloc[idx].values
        X = X.astype('float32')
        X = torch.from_numpy(X)
        
        y = self.df['value'].iloc[idx]
        y = y.astype('long')
        y = torch.tensor(y)

        return X, y

# %%
DATA_PATH = '/home/capstone22/WildFIrePrediction/isaac_data/processed_data_old'

FEATURES = [
 'Road_Dist',
 'Elec_Dist',
 'Cultivated_Prop',
 'aet__mean_Normal',
 'cwd__mean_Normal',
 'aet__mean_ThreeYear_Dev',
 'cwd__mean_ThreeYear_Dev',
 'Mean_Housing_Dens_25km',
 'FFWI',
 'value']

# %%
class DeepNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(len(FEATURES)-1, 64)
        self.fc2 = nn.Linear(64, 128)
        self.fc3 = nn.Linear(128, 32)
        self.fc4 = nn.Linear(32, 2)
        
    def forward (self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %%
trainset = IsaacDS('train', FEATURES, DATA_PATH)
validset = IsaacDS('valid', FEATURES, DATA_PATH)
testset = IsaacDS('test', FEATURES, DATA_PATH)

# %%
trainset[0]
# Out:
# (tensor([1.1000e+04, 1.0000e+01, 0.0000e+00, 2.3528e+01, 5.2955e+01, 3.1711e+00,
#          7.5091e+00, 2.6736e+01, 4.0219e+01]),
#  tensor(0))

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size = 64, shuffle=True, num_workers=16)
validloader = torch.utils.data.DataLoader(validset, batch_size = 64, shuffle=False, num_workers=8)
testloader = torch.utils.data.DataLoader(testset, batch_size = 64, shuffle=False, num_workers=8)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = DeepNN()
model = nn.DataParallel(model)
model.to(device)
# Out:
# DataParallel(
#   (module): DeepNN(
#     (fc1): Linear(in_features=9, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=128, bias=True)
#     (fc3): Linear(in_features=128, out_features=32, bias=True)
#     (fc4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %%
summary(model, (64, 16))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torchsummary/torchsummary.py in summary(model, input_data, batch_dim, branching, col_names, col_width, depth, device, dtypes, verbose, *args, **kwargs)
#     139             with torch.no_grad():
# --> 140                 _ = model.to(device)(*x, *args, **kwargs)  # type: ignore[misc]
#     141         except Exception as e:
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     166         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
# --> 167         outputs = self.parallel_apply(replicas, inputs, kwargs)
#     168         return self.gather(outputs, self.output_device)
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/parallel/data_parallel.py in parallel_apply(self, replicas, inputs, kwargs)
#     176     def parallel_apply(self, replicas, inputs, kwargs):
# --> 177         return parallel_apply(replicas, inputs, kwargs, self.device_ids[:len(replicas)])
#     178
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/parallel/parallel_apply.py in parallel_apply(modules, inputs, kwargs_tup, devices)
#      85         if isinstance(output, ExceptionWrapper):
# ---> 86             output.reraise()
#      87         outputs.append(output)
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/_utils.py in reraise(self)
#     428             raise self.exc_type(message=msg)
# --> 429         raise self.exc_type(msg)
#     430
#
# RuntimeError: Caught RuntimeError in replica 0 on device 0.
# Original Traceback (most recent call last):
#   File "/home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/parallel/parallel_apply.py", line 61, in _worker
#     output = module(*input, **kwargs)
#   File "/home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "<ipython-input-24-80043086f310>", line 10, in forward
#     x = F.relu(self.fc1(x))
#   File "/home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/modules/linear.py", line 94, in forward
#     return F.linear(input, self.weight, self.bias)
#   File "/home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/functional.py", line 1753, in linear
#     return torch._C._nn.linear(input, weight, bias)
# RuntimeError: mat1 dim 1 must match mat2 dim 0
#
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-ebeb9799f0b4> in <module>
# ----> 1 summary(model, (64, 16))
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torchsummary/torchsummary.py in summary(model, input_data, batch_dim, branching, col_names, col_width, depth, device, dtypes, verbose, *args, **kwargs)
#     144                 "Failed to run torchsummary. See above stack traces for more details. "
#     145                 "Executed layers up to: {}".format(executed_layers)
# --> 146             ) from e
#     147         finally:
#     148             if hooks is not None:
#
# RuntimeError: Failed to run torchsummary. See above stack traces for more details. Executed layers up to: []

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
# defining custom loss function
def custom_loss(y_true,y_pred):
    # mean abs error implementation from keras
#     mae_tensor = K.mean(K.abs(y_pred - y_true), axis=-1)
    # +ve means real more than predicted, penalize
    # -ve means predicted more than real, normal loss
    diff_tensor = y_true - y_pred
    
    exponential_tensor = torch.exp(diff_tensor  * 100.0 / 30.0)
#     exponential_tensor = K.exp(diff_tensor * 100.0 / 20.0)
#     exponential_tensor = K.exp(diff_tensor * 100.0 / 11.0)
    exponential_tensor = torch.clip(exponential_tensor, min=1.0, max=10000.0)
    abs_tensor = torch.abs(diff_tensor)
    output_tensor = torch.mean(abs_tensor * exponential_tensor)
#     clipped_tensor = K.clip(exponential_tensor, 1.0, 10000.0)
    return output_tensor

# %%
"""
    Parameters: 
    y_true: true binary labels of fire/no fire
    y_pred: prediction values from model
"""

def plot_roc_curve(y_true, y_pred):
    try:
#         fpr, tpr, thresholds = roc_auc_score(y_true, y_pred)
#         plt.plot(fpr, tpr)
#         plt.xlabel('False Positive Rate')
#         plt.ylabel('True Positive Rate')

        print(f'AUC score: {roc_auc_score(y_true, y_pred)}')
    except ValueError:
#         print(f'only 1 class present in y_true')
        pass

# %%
epochs = 50

for e in range(epochs):
    start = time()
    running_loss = 0
    model.train()
    
    for X, y in trainloader:
        
        log_ps = model(X.to(device))
        
        prob = log_ps.clone()
        prob = np.exp(prob.cpu().detach().numpy())[:, 1]
        
#         loss = criterion(log_ps, y.to(device))
        loss = custom_loss(log_ps, y.to(device).view(-1,1))
    
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print(f'Epoch {e}: Training loss: {running_loss/len(trainloader)}', end=' ')
        
    model.eval()
    with torch.no_grad():
        total = 0
        correct = 0
        y_true, y_pred = [], []
        for X, y in validloader: 
            log_ps = model(X.to(device)).cpu()
            mx_index = torch.argmax(log_ps, dim=1)
#             plot_roc_curve(y, mx_index)
            total += y.numel()
            correct += sum(mx_index==y).item()
            
            y_true.extend(y)
            y_pred.extend(mx_index)
        
        accuracy = correct/total*100
        print(f'Validation test accuracy {accuracy:.2f}')
        plot_roc_curve(y_true, y_pred)
        
    print(f'Epoch time: {round(time()-start, 2)}')
# Out:
# Epoch 0: Training loss: 1.8837024127910782 Validation test accuracy 5.71
# AUC score: 0.499568908928721
# Epoch time: 32.24
# Epoch 1: Training loss: 0.7745817047773228 Validation test accuracy 44.42
# AUC score: 0.6125028929324496
# Epoch time: 34.3
# Epoch 2: Training loss: 0.7174764997060682 Validation test accuracy 4.40
# AUC score: 0.5118989802433177
# Epoch time: 35.01
# Epoch 3: Training loss: 0.7071658887698417 Validation test accuracy 90.13
# AUC score: 0.4763322014116547
# Epoch time: 37.43
# Epoch 4: Training loss: 0.7022776667765144 Validation test accuracy 52.67
# AUC score: 0.4486855574219405
# Epoch time: 39.01
# Epoch 5: Training loss: 0.6986525838983723 Validation test accuracy 31.20
# AUC score: 0.5679713136657796
# Epoch time: 42.52
# Epoch 6: Training loss: 0.7084146313993731 Validation test accuracy 80.40
# AUC score: 0.4588924329874868
# Epoch time: 44.37
# Epoch 7: Training loss: 0.6982695470615907 Validation test accuracy 54.19
# AUC score: 0.6459166238411017
# Epoch time: 46.99
# Epoch 8: Training loss: 0.6980553072229533 Validation test accuracy 60.98
# AUC score: 0.47474152992712537
# Epoch time: 46.52
# Epoch 9: Training loss: 0.6981011009414609 Validation test accuracy 61.50
# AUC score: 0.47425298144575034
# Epoch time: 52.52
# Epoch 10: Training loss: 0.6979973075943579 Validation test accuracy 50.56
# AUC score: 0.4001378977842304
# Epoch time: 52.44
# Epoch 11: Training loss: 0.6980279347718105 Validation test accuracy 94.56
# AUC score: 0.4828598767843495
# Epoch time: 55.04
# Epoch 12: Training loss: 0.6979856449521968 Validation test accuracy 85.07
# AUC score: 0.5077033053418379
# Epoch time: 53.05
# Epoch 13: Training loss: 0.6979856644009294 Validation test accuracy 93.39
# AUC score: 0.48012310651351964
# Epoch time: 55.14
# Epoch 14: Training loss: 0.6979856456004879 Validation test accuracy 75.72
# AUC score: 0.5237485278544858
# Epoch time: 56.22
# Epoch 15: Training loss: 0.6979856342363266 Validation test accuracy 56.78
# AUC score: 0.4662386357107112
# Epoch time: 56.2
# Epoch 16: Training loss: 0.6979856341600571 Validation test accuracy 14.92
# AUC score: 0.49224629905265893
# Epoch time: 55.44
# Epoch 17: Training loss: 0.6979856341600571 Validation test accuracy 99.03
# AUC score: 0.4990676812981908
# Epoch time: 57.73
# Epoch 18: Training loss: 0.6979856340456527 Validation test accuracy 99.19
# AUC score: 0.499874010986242
# Epoch time: 57.95
# Epoch 19: Training loss: 0.6979856344270005 Validation test accuracy 0.80
# AUC score: 0.5001007912110065
# Epoch time: 55.85
# Epoch 20: Training loss: 0.6979856347702134 Validation test accuracy 99.20
# AUC score: 0.4999496043944968
# Epoch time: 57.5
# Epoch 21: Training loss: 0.6979856351134263 Validation test accuracy 99.09
# AUC score: 0.4993952527339616
# Epoch time: 59.95
# Epoch 22: Training loss: 0.6979856355329088 Validation test accuracy 0.80
# AUC score: 0.5000503956055031
# Epoch time: 58.37
# Epoch 23: Training loss: 0.6980056286773388 Validation test accuracy 0.80
# AUC score: 0.5000503956055031
# Epoch time: 60.1
# Epoch 24: Training loss: 0.6979856347320786 Validation test accuracy 0.80
# AUC score: 0.5001007912110065
# Epoch time: 60.97
# Epoch 25: Training loss: 0.6979856351896958 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 63.34
# Epoch 26: Training loss: 0.69798563450327 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 61.18
# Epoch 27: Training loss: 0.697985634999022 Validation test accuracy 0.80
# AUC score: 0.5001007912110065
# Epoch time: 60.67
# Epoch 28: Training loss: 0.6979856342744614 Validation test accuracy 0.80
# AUC score: 0.5001007912110065
# Epoch time: 61.5
# Epoch 29: Training loss: 0.6979856346939438 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 62.62
# Epoch 30: Training loss: 0.6981416517011797 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 61.75
# Epoch 31: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 61.34
# Epoch 32: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 59.8
# Epoch 33: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 52.48
# Epoch 34: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 55.25
# Epoch 35: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 57.76
# Epoch 36: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 59.72
# Epoch 37: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 58.26
# Epoch 38: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 57.05
# Epoch 39: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 57.04
# Epoch 40: Training loss: 0.6980056277621044 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 57.49
# Epoch 41: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 60.39
# Epoch 42: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 60.97
# Epoch 43: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 61.19
# Epoch 44: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 62.69
# Epoch 45: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 59.93
# Epoch 46: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 65.43
# Epoch 47: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 60.12
# Epoch 48: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 61.81
# Epoch 49: Training loss: 0.6979856341600571 Validation test accuracy 99.22
# AUC score: 0.5
# Epoch time: 56.63

# %%
for X, y in testloader:
    log_ps = model(X.to(device)).cpu()
    mx_index = torch.argmax(log_ps, dim=1)
    total += y.numel()
    correct += sum(mx_index==y).item()

    y_true.extend(y)
    y_pred.extend(mx_index)

accuracy = correct/total*100
print(f'Validation test accuracy {accuracy:.2f}')
plot_roc_curve(y_true, y_pred)
