# %%
import pandas as pd
import numpy as np
import os
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
from torch.utils.data import Dataset
from torchsummary import summary

from time import time 

import tqdm

import tensorflow.keras.backend as K

import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve

# %%
class IsaacDS(Dataset):
    def __init__(self, split, features, data_dir):
        self.split = split
        self.features = features
        self.data_dir = data_dir
        self.df = self.getdf()
      

    def getdf(self):
        path = os.path.join(self.data_dir, f'isaac_{self.split}.csv')
        df = pd.read_csv(path)
        df = df[self.features]
        
        return df
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        X = self.df.drop(columns=['value']).iloc[idx].values
        X = X.astype('float32')
        X = torch.from_numpy(X)
        
        y = self.df['value'].iloc[idx]
        y = y.astype('long')
        y = torch.tensor(y)

        return X, y

# %%
DATA_PATH = '/home/capstone22/WildFIrePrediction/isaac_data/processed_data_old'

FEATURES = [
 'Road_Dist',
 'Elec_Dist',
 'Cultivated_Prop',
 'aet__maximum_Normal',
 'aet__mean_Normal',
 'aet__minimum_Normal',
 'cwd__maximum_Normal',
 'cwd__mean_Normal',
 'cwd__minimum_Normal',
 'pck__maximum_Normal',
 'pck__mean_Normal',
 'aet__mean_ThreeYear_Dev',
 'cwd__mean_ThreeYear_Dev',
 'pck__minimum_Normal',
 'Mean_Housing_Dens_25km',
 'FFWI',
 'value']

# %%
class DeepNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(16, 64)
        self.fc2 = nn.Linear(64, 128)
        self.fc3 = nn.Linear(128, 32)
        self.fc4 = nn.Linear(32, 2)
        
    def forward (self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.log_softmax(self.fc4(x), dim=1)
        
        return x

# %%
trainset = IsaacDS('train', FEATURES, DATA_PATH)
validset = IsaacDS('valid', FEATURES, DATA_PATH)
testset = IsaacDS('test', FEATURES, DATA_PATH)

# %%
trainset[0]
# Out:
# (tensor([1.1000e+04, 1.0000e+01, 0.0000e+00, 6.9257e+01, 2.3528e+01, 1.9532e+00,
#          9.6359e+01, 5.2955e+01, 1.9432e+01, 2.9524e+02, 9.1280e+01, 3.1711e+00,
#          7.5091e+00, 0.0000e+00, 2.6736e+01, 4.0219e+01]),
#  tensor(0))

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size = 64, shuffle=True, num_workers=16)
validloader = torch.utils.data.DataLoader(validset, batch_size = 64, shuffle=False, num_workers=8)
testloader = torch.utils.data.DataLoader(testset, batch_size = 64, shuffle=False, num_workers=8)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = DeepNN()
model = nn.DataParallel(model)
model.to(device)
# Out:
# DataParallel(
#   (module): DeepNN(
#     (fc1): Linear(in_features=16, out_features=64, bias=True)
#     (fc2): Linear(in_features=64, out_features=128, bias=True)
#     (fc3): Linear(in_features=128, out_features=32, bias=True)
#     (fc4): Linear(in_features=32, out_features=2, bias=True)
#   )
# )

# %%
summary(model, (64, 16))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─DeepNN: 1-1                            []                        --
# ├─DeepNN: 1                              []                        --
# |    └─Linear: 2-1                       []                        1,088
# ├─DeepNN: 1-2                            [-1, 64, 2]               --
# ├─DeepNN: 1                              []                        --
# |    └─Linear: 2-2                       [-1, 64, 64]              --
# |    └─Linear: 2-3                       [-1, 64, 128]             8,320
# |    └─Linear: 2-4                       [-1, 64, 32]              4,128
# |    └─Linear: 2-5                       [-1, 64, 2]               66
# |    └─Linear: 2-6                       [-1, 64, 128]             --
# |    └─Linear: 2-7                       [-1, 64, 32]              --
# |    └─Linear: 2-8                       [-1, 64, 2]               --
# ==========================================================================================
# Total params: 13,602
# Trainable params: 13,602
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.13
# ==========================================================================================
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─DeepNN: 1-1                            []                        --
# ├─DeepNN: 1                              []                        --
# |    └─Linear: 2-1                       []                        1,088
# ├─DeepNN: 1-2                            [-1, 64, 2]               --
# ├─DeepNN: 1                              []                        --
# |    └─Linear: 2-2                       [-1, 64, 64]              --
# |    └─Linear: 2-3                       [-1, 64, 128]             8,320
# |    └─Linear: 2-4                       [-1, 64, 32]              4,128
# |    └─Linear: 2-5                       [-1, 64, 2]               66
# |    └─Linear: 2-6                       [-1, 64, 128]             --
# |    └─Linear: 2-7                       [-1, 64, 32]              --
# |    └─Linear: 2-8                       [-1, 64, 2]               --
# ==========================================================================================
# Total params: 13,602
# Trainable params: 13,602
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.08
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.13
# ==========================================================================================

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
# defining custom loss function
def custom_loss(y_true,y_pred):
    # mean abs error implementation from keras
#     mae_tensor = K.mean(K.abs(y_pred - y_true), axis=-1)
    # +ve means real more than predicted, penalize
    # -ve means predicted more than real, normal loss
    diff_tensor = y_true - y_pred
    
    exponential_tensor = torch.exp(diff_tensor  * 100.0 / 30.0)
#     exponential_tensor = K.exp(diff_tensor * 100.0 / 20.0)
#     exponential_tensor = K.exp(diff_tensor * 100.0 / 11.0)
    exponential_tensor = torch.clip(exponential_tensor, min=1.0, max=10000.0)
    abs_tensor = torch.abs(diff_tensor)
    output_tensor = torch.mean(abs_tensor * exponential_tensor)
#     clipped_tensor = K.clip(exponential_tensor, 1.0, 10000.0)
    return output_tensor

# %%
epochs = 50

for e in range(epochs):
    start = time()
    running_loss = 0
    model.train()
    
    for X, y in trainloader:
        
        log_ps = model(X.to(device))
        
        prob = log_ps.clone()
        prob = np.exp(prob.cpu().detach().numpy())[:, 1]
        
#         loss = criterion(log_ps, y.to(device))
        loss = custom_loss(log_ps, y.to(device).view(-1,1))
    
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    else:
        print(f'Epoch {e}: Training loss: {running_loss/len(trainloader)}', end=' ')
        
    model.eval()
    with torch.no_grad():
        total = 0
        correct = 0
        for X, y in validloader: 
            log_ps = model(X.to(device)).cpu()
            mx_index = torch.argmax(log_ps, dim=1)
            plot_roc_curve(y, mx_index)
            total += y.numel()
            correct += sum(mx_index==y).item()
        
        accuracy = correct/total*100
        print(f'Validation test accuracy {accuracy:.2f}')
        
    print(f'Epoch time: {round(time()-start, 2)}')
# Out:
# Epoch 0: Training loss: 0.6979946727487267 AUC score: 0.7619047619047619
# only 1 class present in y_true
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8174603174603174
# AUC score: 0.7936507936507937
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8095238095238095
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5725806451612904
# AUC score: 0.8064516129032258
# AUC score: 0.8095238095238095
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8253968253968254
# only 1 class present in y_true
# AUC score: 0.3650793650793651
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8253968253968254
# AUC score: 0.5725806451612904
# AUC score: 0.7380952380952381
# AUC score: 0.8095238095238095
# only 1 class present in y_true
# AUC score: 0.587431693989071
# AUC score: 0.8333333333333334
# only 1 class present in y_true
# AUC score: 0.6500000000000001
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.3015873015873016
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# AUC score: 0.7936507936507937
# AUC score: 0.746031746031746
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# AUC score: 0.746031746031746
# only 1 class present in y_true
# AUC score: 0.8333333333333334
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.532258064516129
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# AUC score: 0.3015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7741935483870968
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8571428571428572
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.30952380952380953
# AUC score: 0.7857142857142857
# AUC score: 0.8650793650793651
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# AUC score: 0.8064516129032258
# only 1 class present in y_true
# AUC score: 0.7983870967741935
# only 1 class present in y_true
# AUC score: 0.7857142857142857
# AUC score: 0.3015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8174603174603174
# AUC score: 0.8015873015873016
# AUC score: 0.8492063492063492
# AUC score: 0.2222222222222222
# only 1 class present in y_true
# AUC score: 0.8412698412698413
# AUC score: 0.753968253968254
# AUC score: 0.31746031746031744
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8174603174603174
# AUC score: 0.8467741935483871
# only 1 class present in y_true
# AUC score: 0.5080645161290323
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# only 1 class present in y_true
# AUC score: 0.8083333333333333
# only 1 class present in y_true
# AUC score: 0.8174603174603174
# only 1 class present in y_true
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# AUC score: 0.8174603174603174
# only 1 class present in y_true
# AUC score: 0.7741935483870968
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# AUC score: 0.7857142857142857
# AUC score: 0.7857142857142857
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# AUC score: 0.8225806451612903
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.29032258064516125
# AUC score: 0.5725806451612904
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7983870967741935
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# AUC score: 0.8174603174603174
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5833333333333334
# AUC score: 0.75
# only 1 class present in y_true
# AUC score: 0.5796610169491526
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8492063492063492
# only 1 class present in y_true
# AUC score: 0.753968253968254
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5403225806451613
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.753968253968254
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# AUC score: 0.7936507936507937
# AUC score: 0.746031746031746
# AUC score: 0.7936507936507937
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# AUC score: 0.3015873015873016
# only 1 class present in y_true
# AUC score: 0.7338709677419355
# only 1 class present in y_true
# AUC score: 0.7580645161290323
# AUC score: 0.6984126984126984
# only 1 class present in y_true
# AUC score: 0.2698412698412699
# AUC score: 0.24603174603174605
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5241935483870968
# AUC score: 0.25396825396825395
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5483870967741936
# AUC score: 0.8095238095238095
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8253968253968254
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8253968253968254
# only 1 class present in y_true
# AUC score: 0.25396825396825395
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7857142857142857
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7619047619047619
# AUC score: 0.8174603174603174
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.29365079365079366
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.25396825396825395
# only 1 class present in y_true
# AUC score: 0.5161290322580645
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.746031746031746
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.2777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.2857142857142857
# AUC score: 0.24603174603174605
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.24603174603174605
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7619047619047619
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# AUC score: 0.7619047619047619
# AUC score: 0.8174603174603174
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# AUC score: 0.7301587301587302
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7380952380952381
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6746031746031746
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7741935483870968
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# Validation test accuracy 56.77
# Epoch time: 54.13
# Epoch 1: Training loss: 0.6979858050419593 AUC score: 0.19047619047619047
# only 1 class present in y_true
# AUC score: 0.6587301587301587
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7619047619047619
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5
# AUC score: 0.7258064516129032
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.753968253968254
# only 1 class present in y_true
# AUC score: 0.8015873015873016
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7142857142857143
# AUC score: 0.5
# AUC score: 0.6825396825396826
# AUC score: 0.746031746031746
# only 1 class present in y_true
# AUC score: 0.5300546448087431
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# AUC score: 0.7
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.746031746031746
# only 1 class present in y_true
# AUC score: 0.7380952380952381
# AUC score: 0.6984126984126984
# AUC score: 0.7222222222222222
# AUC score: 0.7222222222222222
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7661290322580645
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.24603174603174605
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7301587301587302
# AUC score: 0.19841269841269843
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.717741935483871
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7936507936507937
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.2777777777777778
# AUC score: 0.7698412698412699
# AUC score: 0.7619047619047619
# only 1 class present in y_true
# AUC score: 0.753968253968254
# AUC score: 0.7016129032258065
# only 1 class present in y_true
# AUC score: 0.7258064516129032
# only 1 class present in y_true
# AUC score: 0.746031746031746
# AUC score: 0.20634920634920634
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7301587301587302
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6666666666666667
# AUC score: 0.6984126984126984
# AUC score: 0.7777777777777778
# AUC score: 0.18253968253968256
# only 1 class present in y_true
# AUC score: 0.753968253968254
# AUC score: 0.626984126984127
# AUC score: 0.19841269841269843
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7222222222222222
# AUC score: 0.8467741935483871
# only 1 class present in y_true
# AUC score: 0.7016129032258065
# only 1 class present in y_true
# AUC score: 0.746031746031746
# only 1 class present in y_true
# AUC score: 0.7083333333333333
# only 1 class present in y_true
# AUC score: 0.6984126984126984
# only 1 class present in y_true
# AUC score: 0.7222222222222222
# only 1 class present in y_true
# AUC score: 0.753968253968254
# only 1 class present in y_true
# AUC score: 0.685483870967742
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# AUC score: 0.7063492063492063
# AUC score: 0.746031746031746
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# AUC score: 0.685483870967742
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.4838709677419355
# AUC score: 0.45967741935483863
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.717741935483871
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# AUC score: 0.18253968253968256
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7301587301587302
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.5916666666666667
# AUC score: 0.7096774193548387
# only 1 class present in y_true
# AUC score: 0.711864406779661
# only 1 class present in y_true
# AUC score: 0.6666666666666667
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# AUC score: 0.2142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.4677419354838709
# AUC score: 0.6984126984126984
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6666666666666667
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7619047619047619
# AUC score: 0.24603174603174605
# AUC score: 0.23809523809523808
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# AUC score: 0.19047619047619047
# AUC score: 0.19841269841269843
# only 1 class present in y_true
# AUC score: 0.7903225806451613
# only 1 class present in y_true
# AUC score: 0.7016129032258065
# AUC score: 0.6904761904761905
# only 1 class present in y_true
# AUC score: 0.23015873015873017
# AUC score: 0.18253968253968256
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.4516129032258064
# AUC score: 0.23015873015873017
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.49193548387096775
# AUC score: 0.753968253968254
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7222222222222222
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# AUC score: 0.19047619047619047
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.23809523809523808
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7777777777777778
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6825396825396826
# AUC score: 0.7222222222222222
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.23015873015873017
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6746031746031746
# only 1 class present in y_true
# AUC score: 0.7741935483870968
# only 1 class present in y_true
# AUC score: 0.7063492063492063
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7142857142857143
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.23015873015873017
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.2222222222222222
# AUC score: 0.6904761904761905
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.19047619047619047
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6825396825396826
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7222222222222222
# only 1 class present in y_true
# AUC score: 0.7698412698412699
# AUC score: 0.7380952380952381
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.746031746031746
# AUC score: 0.6984126984126984
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6825396825396826
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.6507936507936508
# only 1 class present in y_true
# only 1 class present in y_true
# AUC score: 0.7096774193548387
# only 1 class present in y_true
# only 1 class present in y_true
# only 1 class present in y_true
# Validation test accuracy 44.52
# Epoch time: 54.84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-1a7191711ece> in <module>
#       6     model.train()
#       7
# ----> 8     for X, y in trainloader:
#       9
#      10         log_ps = model(X.to(device))
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     515             if self._sampler_iter is None:
#     516                 self._reset()
# --> 517             data = self._next_data()
#     518             self._num_yielded += 1
#     519             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1180
#    1181             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1182             idx, data = self._get_data()
#    1183             self._tasks_outstanding -= 1
#    1184             if self._dataset_kind == _DatasetKind.Iterable:
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1146         else:
#    1147             while True:
# -> 1148                 success, data = self._try_get_data()
#    1149                 if success:
#    1150                     return data
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     984         #   (bool: whether successfully get data, any: data if successful else None)
#     985         try:
# --> 986             data = self._data_queue.get(timeout=timeout)
#     987             return (True, data)
#     988         except Exception as e:
#
# /usr/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     111                 self._rlock.release()
#     112         # unserialize the data after having released the lock
# --> 113         return _ForkingPickler.loads(res)
#     114
#     115     def qsize(self):
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/multiprocessing/reductions.py in rebuild_tensor(cls, storage, metadata)
#      86 def rebuild_tensor(cls, storage, metadata):
#      87     storage_offset, size, stride, requires_grad = metadata
# ---> 88     t = torch._utils._rebuild_tensor(storage, storage_offset, size, stride)
#      89     if cls == torch.nn.parameter.Parameter:
#      90         # we have to pass requires_grad into constructor, rather than set it as an
#
# ~/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/_utils.py in _rebuild_tensor(storage, storage_offset, size, stride)
#     129
#     130
# --> 131 def _rebuild_tensor(storage, storage_offset, size, stride):
#     132     # first construct a tensor with the correct dtype/device
#     133     t = torch.tensor([], dtype=storage.dtype, device=storage.device)
#
# KeyboardInterrupt:

# %%
"""
    Parameters: 
    y_true: true binary labels of fire/no fire
    y_pred: prediction values from model
"""

def plot_roc_curve(y_true, y_pred):
    try:
#         fpr, tpr, thresholds = roc_auc_score(y_true, y_pred)
#         plt.plot(fpr, tpr)
#         plt.xlabel('False Positive Rate')
#         plt.ylabel('True Positive Rate')

        print(f'AUC score: {roc_auc_score(y_true, y_pred)}')
    except ValueError:
#         print(f'only 1 class present in y_true')
        pass

# %%
# y = y.cpu().detach().numpy()
# import numpy
# y = y.astype(numpy.int64)
y = np.int64(y)

# %%
# mx_index = mx_index.cpu().detach().numpy()
# mx_index = mx_index.astype(np.int64)
mx_index = np.int64(mx_index)

# %%
type(y)
type(mx_index)
# Out:
# numpy.ndarray

# %%
plot_roc_curve(a, b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-1ad71998480c> in <module>
# ----> 1 plot_roc_curve(a, b)
#
# <ipython-input-46-85af3589d3df> in plot_roc_curve(y_true, y_pred)
#       7 def plot_roc_curve(y_true, y_pred):
#       8     try:
# ----> 9         fpr, tpr, thresholds = roc_auc_score(y_true, y_pred)
#      10         plt.plot(fpr, tpr)
#      11         plt.xlabel('False Positive Rate')
#
# TypeError: 'numpy.float64' object is not iterable
