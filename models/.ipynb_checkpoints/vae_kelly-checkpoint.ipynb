# %%
import os
import copy

import math
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim 
from torch import Tensor
from torch.utils.data import Dataset

from time import time 
from torchinfo import summary

import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve

# %%
# TODOs:
# - try bce vs. mse loss
# - train on images with both images containing 1s and images of all 0s
# - train w/ images only containing 1s
# - choose validation model based on f1 score (get classification from the output probability)
# - try different features
# - try different patch sizes (64x64 and 128x128 are preprocessed already but you can run the preprocess script for other sizes)
# - Try different network hyperparameters
# - Try an autoencoder instead of a variational autoencoder

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f'Using device: {device}')
# Out:
# Using device: cuda:0

# %%
# target map fire value
FIRE_VAL = 1

DATA_DIR = '/home/capstone22/WildFIrePrediction/isaac_data/processed_data_64'

# using features recommended by isaac - pck
# FEATURES = [2,3,4,12,13,14,26,27,28,48,49,50,53] 
FEATURES = list(range(2,54))

# %% [markdown]
# ## Load dataset

# %%
class IsaacDSImage(Dataset):
    """A Dataset class for image patches.
    """
    def __init__(self, split, features, data_dir, has_fire_only=False, min_fire=20):
        """Initialize dataset class.

        Args:
            split (str): Train/Valid/Test to be retrieved.
            features (list[int]): A list of channels indexes to used.
            data_dir (str): The path to the data directory.
            has_fire_only (bool, optional): Only load patches with fire. Defaults to False.
            min_fire (int, optional): Minimum number of fire pixel. Defaults to 20.
        """
        self.split = split
        self.features = features
        self.data_dir = data_dir
        self.split_map = {
            'train': np.arange(2003, 2013),
            'valid': np.arange(2013, 2015),
            'test': np.arange(2015, 2018)
        }
        self.has_fire_only = has_fire_only
        self.min_fire = min_fire
        self.data_x, self.data_y = self.get_data()
      

    def get_data(self):
        """Return the feature maps and target maps.
        """
        years = self.split_map[self.split]
        all_X, all_y = [], []
        
        # load patches from all years
        for year in years:
            X_path = os.path.join(self.data_dir, f'{year}.npy')
            y_path = os.path.join(self.data_dir, f'{year}_TD.npy')
            
            X = np.load(X_path, allow_pickle=True)
            y = np.load(y_path, allow_pickle=True)
            
            X = X[:,self.features,:,:]
            
            all_X.append(X)
            all_y.append(y)

        all_X = np.concatenate(all_X, axis=0)
        all_y = np.concatenate(all_y, axis=0)

        # only retain patches with fire
        if(self.has_fire_only):
            fire_indexes = []
            for i, patch in enumerate(all_y):
                if(np.any(patch == FIRE_VAL) and np.count_nonzero(patch == FIRE_VAL) > self.min_fire):
                    fire_indexes.append(i)
            
            all_X = all_X[fire_indexes]
            all_y = all_y[fire_indexes]

        return all_X, all_y
        
    def __len__(self):
        """Return the number of samples.
        """
        return len(self.data_x)
    
    def __getitem__(self, idx: int):
        """Return feature map and target map at index.
        """

        X = self.data_x[idx]
        y = self.data_y[idx]
        
        y = np.expand_dims(y, axis=0)
        
        X = X.astype('float32')
        y = y.astype('float32')
        
        X = torch.from_numpy(X)
        y = torch.from_numpy(y)

        return X, y

# %%
trainset = IsaacDSImage('train', FEATURES, DATA_DIR, has_fire_only=True, min_fire=10)
valset = IsaacDSImage('valid', FEATURES, DATA_DIR)
testset = IsaacDSImage('test', FEATURES, DATA_DIR)

print(f'Training set samples: {trainset.__len__()}')
print(f'Validation set samples: {valset.__len__()}')
print(f'Testing set samples: {testset.__len__()}')
# Out:
# Training set samples: 233
# Validation set samples: 570
# Testing set samples: 855

# %%
# validation and testing loader need to have batch size of 80 for full map reconstruction
batch_size = 8
patches_per_image = valset.__len__() // 2
trainloader = torch.utils.data.DataLoader(trainset, batch_size = batch_size, shuffle=True, num_workers=0)
valloader = torch.utils.data.DataLoader(valset, batch_size = patches_per_image, shuffle=False, num_workers=0)
testloader = torch.utils.data.DataLoader(testset, batch_size = patches_per_image, shuffle=False, num_workers=0)

# %%
# # check data to make sure they look ok

# for i in range(trainset.__len__()):
#     X, y = trainset[i]
#     print(X.shape, y.shape)
#     print(trainset.__len__())

#     # plt.imshow(X[0, :,:])
#     # print(np.nanmin(X), np.nanmax(X))
#     plt.imshow(y[0])
#     plt.show()

# %% [markdown]
# ## Define Variational Autoencoder Model

# %%
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)
    
class UnFlatten(nn.Module):
    def forward(self, input):
        # should be the same as non-flatten encoder output shape
        return input.view(input.size(0), 128, 2, 2)

# %%
# VAE Model from https://github.com/AntixK/PyTorch-VAE/blob/master/models/vanilla_vae.py
class VanillaVAE(nn.Module):

    def __init__(self,
                 in_channels: int,
                 latent_dim: int,
                 hidden_dims: list = None,
                 kernel_size: int = 5,
                 **kwargs) -> None:
        super(VanillaVAE, self).__init__()

        self.latent_dim = latent_dim # size of z (computed from encoder output(mean&std) and ε)
        self.kernel_size = kernel_size
        self.stride_size = self.kernel_size - 1

        modules = []
        # hidden_dims: # of filters for CNN
        if hidden_dims is None:
            hidden_dims = [32, 64, 128, 256, 512] # five hiddens_dims for images 64x64, six for 128x128
        
        self.last_hidden_dim = hidden_dims[-1]
        self.enc_img_width = int(64 / self.stride_size**(len(hidden_dims))) # encoder output img width
        self.enc_img_height = int(64 / self.stride_size**(len(hidden_dims)))
        self.enc_size = self.enc_img_width * self.enc_img_height

        # Build Encoder
        for i, h_dim in enumerate(hidden_dims):
            if(i==0):
                modules.append(
                    nn.Sequential(
                        # The mean and standard-deviation are calculated per-dimension separately for each object in a mini-batch.
                        nn.InstanceNorm2d(len(FEATURES), track_running_stats=False), # normalize across channel
                        nn.Conv2d(in_channels, out_channels=h_dim,
                                kernel_size=self.kernel_size, stride=self.stride_size, padding  = 1),
                        nn.BatchNorm2d(h_dim),
                        nn.LeakyReLU())
                )
            else:
                modules.append(
                    nn.Sequential(
                        nn.Conv2d(in_channels, out_channels=h_dim,
                                kernel_size=self.kernel_size, stride=self.stride_size, padding  = 1),
                        nn.BatchNorm2d(h_dim),
                        nn.LeakyReLU())
                )
            in_channels = h_dim

        self.encoder = nn.Sequential(*modules)
        self.fc_mu = nn.Linear(hidden_dims[-1]*self.enc_size, latent_dim)
        self.fc_var = nn.Linear(hidden_dims[-1]*self.enc_size, latent_dim)


        # Build Decoder
        modules = []

        self.decoder_input = nn.Linear(latent_dim, hidden_dims[-1] * self.enc_size)

        hidden_dims.reverse()

        for i in range(len(hidden_dims) - 1):
            modules.append(
                nn.Sequential(
                    nn.ConvTranspose2d(hidden_dims[i],
                                       hidden_dims[i + 1],
                                       kernel_size=self.kernel_size,
                                       stride=self.stride_size,
                                       padding=1,
                                       output_padding=1),
                    nn.BatchNorm2d(hidden_dims[i + 1]),
                    nn.LeakyReLU())
            )



        self.decoder = nn.Sequential(*modules)

        self.final_layer = nn.Sequential(
                            nn.ConvTranspose2d(hidden_dims[-1],
                                               hidden_dims[-1],
                                               kernel_size=self.kernel_size,
                                               stride=self.stride_size,
                                               padding=1,
                                               output_padding=1),
                            nn.BatchNorm2d(hidden_dims[-1]),
                            nn.LeakyReLU(),
                            # nn.Conv2d(hidden_dims[-1], out_channels= 1,
                            #           kernel_size=self.kernel_size, padding= 1),
                            nn.Conv2d(hidden_dims[-1], out_channels= 1,
                                      kernel_size=1),
                            nn.Sigmoid())

    def encode(self, input: Tensor) -> list:
        """
        Encodes the input by passing through the encoder network
        and returns the latent codes.
        :param input: (Tensor) Input tensor to encoder [N x C x H x W] (batch x # channel x height x width)
        :return: (Tensor) List of latent codes
        """
        result = self.encoder(input)
        # print(f'Encoder output shape: {result.shape}')
        result = torch.flatten(result, start_dim=1)
        # print(f'Flatten encoder output shape: {result.shape}')


        # Split the result into mu and var components
        # of the latent Gaussian distribution
        # print(f'Latent space expected shape: {self.fc_mu}')
        mu = self.fc_mu(result)
        log_var = self.fc_var(result)

        return [mu, log_var]

    def decode(self, z: Tensor) -> Tensor:
        """
        Maps the given latent codes
        onto the image space.
        :param z: (Tensor) [B x D]
        :return: (Tensor) [B x C x H x W]
        """
        result = self.decoder_input(z)
        result = result.view(-1, self.last_hidden_dim, self.enc_img_height, self.enc_img_width)
        result = self.decoder(result)
        result = self.final_layer(result)
        return result

    def reparameterize(self, mu: Tensor, logvar: Tensor) -> Tensor:
        """
        Reparameterization trick to sample from N(mu, var) from
        N(0,1) (computing z).
        :param mu: (Tensor) Mean of the latent Gaussian [B x D]
        :param logvar: (Tensor) Standard deviation of the latent Gaussian [B x D]
        :return: (Tensor) [B x D]
        """
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return eps * std + mu

    def forward(self, input: Tensor, **kwargs) -> list:
        mu, log_var = self.encode(input)
        z = self.reparameterize(mu, log_var)
        return  [self.decode(z), mu, log_var]

    #kld - match latent space distribution to gaussian
    #bce - reconstruction loss
    #loss - sum of the two
    def loss_function(self,
                      *args,
                      **kwargs) -> dict:
        """
        Computes the VAE loss function.
        KL(N(\mu, \sigma), N(0, 1)) = \log \frac{1}{\sigma} + \frac{\sigma^2 + \mu^2}{2} - \frac{1}{2}
        :param args:
        :param kwargs:
        :return:
        """
        recons = args[0]
        input = args[1]
        mu = args[2]
        log_var = args[3]

        # distribution loss weight 
        kld_weight = kwargs['M_N'] # Account for the minibatch samples from the dataset, batch size / all training images

        # choose one
        # size_average = False -> sum of all pixels's loss 
        
#         recons_loss =F.mse_loss(recons, input, size_average=False)
        recons_loss =F.binary_cross_entropy(recons, input, size_average=False) 

        kld_loss = torch.mean(-0.5 * torch.sum(1 + log_var - mu ** 2 - log_var.exp(), dim = 1), dim = 0)

        loss = recons_loss + kld_weight * kld_loss
        return {'loss': loss, 'Reconstruction_Loss':recons_loss.detach(), 'KLD':-kld_loss.detach()}

    # not used
    def sample(self,
               num_samples:int,
               current_device: int, **kwargs) -> Tensor:
        """
        Samples from the latent space and return the corresponding
        image space map.
        :param num_samples: (Int) Number of samples
        :param current_device: (Int) Device to run the model
        :return: (Tensor)
        """
        z = torch.randn(num_samples,
                        self.latent_dim)

        z = z.to(current_device)

        samples = self.decode(z)
        return samples

    def generate(self, x: Tensor, **kwargs) -> Tensor:
        """
        Given an input image x, returns the reconstructed image
        :param x: (Tensor) [B x C x H x W]
        :return: (Tensor) [B x C x H x W]
        """

        return self.forward(x)[0]

# %% [markdown]
# # Training and Validation

# %%
model = VanillaVAE(in_channels=len(FEATURES), 
                   latent_dim=1024,
                   hidden_dims = [64, 128],
                   kernel_size=5,
                  ).to(device)
summary(model, input_size=(batch_size, len(FEATURES), 64, 64))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# VanillaVAE                               --                        --
# ├─Sequential: 1-1                        [8, 128, 4, 4]            --
# │    └─Sequential: 2-1                   [8, 64, 16, 16]           --
# │    │    └─InstanceNorm2d: 3-1          [8, 52, 64, 64]           --
# │    │    └─Conv2d: 3-2                  [8, 64, 16, 16]           83,264
# │    │    └─BatchNorm2d: 3-3             [8, 64, 16, 16]           128
# │    │    └─LeakyReLU: 3-4               [8, 64, 16, 16]           --
# │    └─Sequential: 2-2                   [8, 128, 4, 4]            --
# │    │    └─Conv2d: 3-5                  [8, 128, 4, 4]            204,928
# │    │    └─BatchNorm2d: 3-6             [8, 128, 4, 4]            256
# │    │    └─LeakyReLU: 3-7               [8, 128, 4, 4]            --
# ├─Linear: 1-2                            [8, 1024]                 2,098,176
# ├─Linear: 1-3                            [8, 1024]                 2,098,176
# ├─Linear: 1-4                            [8, 2048]                 2,099,200
# ├─Sequential: 1-5                        [8, 64, 16, 16]           --
# │    └─Sequential: 2-3                   [8, 64, 16, 16]           --
# │    │    └─ConvTranspose2d: 3-8         [8, 64, 16, 16]           204,864
# │    │    └─BatchNorm2d: 3-9             [8, 64, 16, 16]           128
# │    │    └─LeakyReLU: 3-10              [8, 64, 16, 16]           --
# ├─Sequential: 1-6                        [8, 1, 64, 64]            --
# │    └─ConvTranspose2d: 2-4              [8, 64, 64, 64]           102,464
# │    └─BatchNorm2d: 2-5                  [8, 64, 64, 64]           128
# │    └─LeakyReLU: 2-6                    [8, 64, 64, 64]           --
# │    └─Conv2d: 2-7                       [8, 1, 64, 64]            65
# │    └─Sigmoid: 2-8                      [8, 1, 64, 64]            --
# ==========================================================================================
# Total params: 6,891,777
# Trainable params: 6,891,777
# Non-trainable params: 0
# Total mult-adds (G): 4.03
# ==========================================================================================
# Input size (MB): 6.82
# Forward/backward pass size (MB): 38.54
# Params size (MB): 27.57
# Estimated Total Size (MB): 72.92
# ==========================================================================================

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
def stitch_imgs(output_imgs: np.ndarray) -> np.ndarray:
    """Stitch map patches together.

    Args:
        output_imgs (np.ndarray): Patches of map.

    Returns:
        np.ndarray: A numpy array of full map.
    """
    patch_size = 64
    HEIGHT = math.ceil(1209/patch_size)*patch_size
    WIDTH = math.ceil(941/patch_size)*patch_size
    arr = np.zeros((HEIGHT, WIDTH))

    _, _, dim_y, dim_x = output_imgs.shape

    for row in range(math.ceil(HEIGHT/dim_y)):
        for col in range(math.ceil(WIDTH/dim_x)):
            x = col*dim_x
            y = row*dim_y
            index = col + row*math.ceil(WIDTH/dim_x)
            arr[y:y+dim_y, x:x+dim_x] = output_imgs[index]

    return arr

# %%
# test stich function
for idx, (input_imgs, output_imgs) in enumerate(valloader): 
    input_imgs = input_imgs.to(device)
    output_imgs = output_imgs.to(device)
    
    plt.imshow(stitch_imgs(output_imgs.cpu()), vmin=0, vmax=1)
    plt.show()

# %%
epochs = 200

# %%
# Training
best_model = copy.deepcopy(model)
lowest_loss = np.inf
patience = np.inf
no_improvement = 0

for epoch in range(epochs):
    model.train()
    losses, bces, klds = 0, 0, 0
    for idx, (input_imgs, output_imgs) in enumerate(trainloader): 
        input_imgs = input_imgs.to(device)
        output_imgs = output_imgs.to(device)
        
        z, mu, log_var = model(input_imgs, labels = output_imgs)
        train_loss = model.loss_function(z, output_imgs, mu, log_var, 
                                          M_N = input_imgs.shape[0]/len(trainset)
                                        ) # sum of all pixels' loss in one batch
        optimizer.zero_grad()
        train_loss['loss'].backward()
        optimizer.step()

        losses += train_loss['loss']
        bces += train_loss['Reconstruction_Loss']
        klds += train_loss['KLD']

    # avg(sum of loss of all pixels per batch)  
    print(f'Epoch {epoch} -> loss: {losses/idx:.3f}, reconstruction loss: {bces/idx:.3f}, KL divergence loss: {klds/idx:.3f}')



    # Validation
    model.eval()
    val_losses, val_bces, val_klds = 0, 0, 0
    for idx, (input_imgs, output_imgs) in enumerate(valloader): 
        input_imgs = input_imgs.to(device)
        output_imgs = output_imgs.to(device)

        recon_images, mu, log_var = model(input_imgs, labels = output_imgs)
        val_loss = model.loss_function(recon_images, output_imgs, mu, log_var, 
                                        M_N = 1.0
                                        )

        val_losses += val_loss['loss']
        val_bces += val_loss['Reconstruction_Loss']
        val_klds += val_loss['KLD']

        # recon_images = recon_images.cpu().detach().numpy()
        # output_imgs = output_imgs.cpu().detach().numpy()


        # fig, axes = plt.subplots(1,2)
        # axes[0].imshow(stitch_imgs(output_imgs), vmin=0, vmax=1)
        # axes[1].imshow(stitch_imgs(recon_images), vmin=0, vmax=1)
        # plt.show()
    
    # loss per patch
    # print(f'Epoch {epoch} -> val loss: {val_losses/idx:.3f}, val reconstruction loss: {val_bces/idx:.3f}, val KL divergence loss: {val_klds/idx:.3f}')
    print(f'====== val reconstruction loss: {val_bces/idx:.3f} ======')

    if(val_bces/idx < lowest_loss):
        lowest_loss = val_bces/idx
        best_model = copy.deepcopy(model)
        no_improvement = 0
    else:
        no_improvement += 1
        if(no_improvement == patience):
            break

# Validation
model = best_model
model.eval()
val_losses, val_bces, val_klds = 0, 0, 0
for idx, (input_imgs, output_imgs) in enumerate(valloader): 
    input_imgs = input_imgs.to(device)
    output_imgs = output_imgs.to(device)

    recon_images = model.generate(input_imgs)

    recon_images = recon_images.cpu().detach().numpy()
    output_imgs = output_imgs.cpu().detach().numpy()


    fig, axes = plt.subplots(1,2)
    axes[0].imshow(stitch_imgs(output_imgs), vmin=0, vmax=1)
    axes[1].imshow(stitch_imgs(recon_images), vmin=0, vmax=1)
    plt.show()

# torch.save(vae.state_dict(), 'vae.torch')
# Out:
# /home/capstone22/WildFIrePrediction/venv/lib/python3.6/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch 0 -> loss: 3104.888, reconstruction loss: 3012.714, KL divergence loss: -2833.040
# ====== val reconstruction loss: 59463.086 ======
# Epoch 1 -> loss: 3112.032, reconstruction loss: 3012.134, KL divergence loss: -4501.436
# ====== val reconstruction loss: 62976.461 ======
# Epoch 2 -> loss: 3094.496, reconstruction loss: 2996.850, KL divergence loss: -3942.385
# ====== val reconstruction loss: 58714.961 ======
# Epoch 3 -> loss: 3072.780, reconstruction loss: 2986.960, KL divergence loss: -2700.351
# ====== val reconstruction loss: 59714.090 ======
# Epoch 4 -> loss: 3100.065, reconstruction loss: 3005.386, KL divergence loss: -2897.510
# ====== val reconstruction loss: 60132.203 ======
# Epoch 5 -> loss: 3097.964, reconstruction loss: 3006.024, KL divergence loss: -2830.060
# ====== val reconstruction loss: 60075.395 ======
# Epoch 6 -> loss: 3104.677, reconstruction loss: 3014.615, KL divergence loss: -2752.543
# ====== val reconstruction loss: 61152.281 ======
# Epoch 7 -> loss: 3119.300, reconstruction loss: 3027.168, KL divergence loss: -2773.822
# ====== val reconstruction loss: 63722.086 ======
# Epoch 8 -> loss: 3088.522, reconstruction loss: 2993.192, KL divergence loss: -4493.086
# ====== val reconstruction loss: 58232.898 ======
# Epoch 9 -> loss: 3108.813, reconstruction loss: 3018.594, KL divergence loss: -2796.464
# ====== val reconstruction loss: 59618.004 ======
# Epoch 10 -> loss: 3083.029, reconstruction loss: 2996.047, KL divergence loss: -2593.281
# ====== val reconstruction loss: 62823.777 ======
# Epoch 11 -> loss: 3088.265, reconstruction loss: 2995.720, KL divergence loss: -2864.853
# ====== val reconstruction loss: 54628.625 ======
# Epoch 12 -> loss: 3094.190, reconstruction loss: 3005.065, KL divergence loss: -2681.963
# ====== val reconstruction loss: 61977.133 ======
# Epoch 13 -> loss: 3085.682, reconstruction loss: 2998.635, KL divergence loss: -2701.522
# ====== val reconstruction loss: 62571.988 ======
# Epoch 14 -> loss: 3100.654, reconstruction loss: 3010.820, KL divergence loss: -2795.588
# ====== val reconstruction loss: 64746.137 ======
# Epoch 15 -> loss: 3075.079, reconstruction loss: 2985.562, KL divergence loss: -2751.476
# ====== val reconstruction loss: 64748.352 ======
# Epoch 16 -> loss: 3079.911, reconstruction loss: 2993.719, KL divergence loss: -2801.406
# ====== val reconstruction loss: 57568.020 ======
# Epoch 17 -> loss: 3091.962, reconstruction loss: 3000.849, KL divergence loss: -2800.282
# ====== val reconstruction loss: 61651.883 ======
# Epoch 18 -> loss: 3085.354, reconstruction loss: 2996.813, KL divergence loss: -2693.533
# ====== val reconstruction loss: 61687.609 ======
# Epoch 19 -> loss: 3119.651, reconstruction loss: 3024.971, KL divergence loss: -2944.065
# ====== val reconstruction loss: 60699.430 ======
# Epoch 20 -> loss: 3087.031, reconstruction loss: 2999.050, KL divergence loss: -2740.330
# ====== val reconstruction loss: 59049.156 ======
# Epoch 21 -> loss: 3103.674, reconstruction loss: 3013.489, KL divergence loss: -2868.969
# ====== val reconstruction loss: 59347.078 ======
# Epoch 22 -> loss: 3106.146, reconstruction loss: 3015.377, KL divergence loss: -2770.813
# ====== val reconstruction loss: 58828.797 ======
# Epoch 23 -> loss: 3087.198, reconstruction loss: 3000.098, KL divergence loss: -2663.022
# ====== val reconstruction loss: 62849.980 ======
# Epoch 24 -> loss: 3090.106, reconstruction loss: 2997.520, KL divergence loss: -2762.755
# ====== val reconstruction loss: 62170.273 ======
# Epoch 25 -> loss: 3078.706, reconstruction loss: 2988.101, KL divergence loss: -2783.731
# ====== val reconstruction loss: 57842.352 ======
# Epoch 26 -> loss: 3077.381, reconstruction loss: 2989.675, KL divergence loss: -2682.679
# ====== val reconstruction loss: 59322.266 ======
# Epoch 27 -> loss: 3103.992, reconstruction loss: 3015.749, KL divergence loss: -2738.885
# ====== val reconstruction loss: 54861.336 ======
# Epoch 28 -> loss: 3090.029, reconstruction loss: 2998.536, KL divergence loss: -2816.547
# ====== val reconstruction loss: 59718.281 ======
# Epoch 29 -> loss: 3074.674, reconstruction loss: 2982.751, KL divergence loss: -2829.067
# ====== val reconstruction loss: 59786.512 ======
# Epoch 30 -> loss: 3108.799, reconstruction loss: 3018.866, KL divergence loss: -2700.773
# ====== val reconstruction loss: 61612.695 ======
# Epoch 31 -> loss: 3091.394, reconstruction loss: 3003.179, KL divergence loss: -2826.800
# ====== val reconstruction loss: 59347.797 ======
# Epoch 32 -> loss: 3089.819, reconstruction loss: 2998.447, KL divergence loss: -2878.121
# ====== val reconstruction loss: 63147.414 ======
# Epoch 33 -> loss: 3103.769, reconstruction loss: 3015.503, KL divergence loss: -2697.645
# ====== val reconstruction loss: 62750.062 ======
# Epoch 34 -> loss: 3084.057, reconstruction loss: 2995.817, KL divergence loss: -2721.295
# ====== val reconstruction loss: 61878.375 ======
# Epoch 35 -> loss: 3091.339, reconstruction loss: 3000.787, KL divergence loss: -2816.473
# ====== val reconstruction loss: 63265.457 ======
# Epoch 36 -> loss: 3083.834, reconstruction loss: 2992.783, KL divergence loss: -2707.758
# ====== val reconstruction loss: 61152.016 ======
# Epoch 37 -> loss: 3092.351, reconstruction loss: 2996.513, KL divergence loss: -3889.742
# ====== val reconstruction loss: 58498.461 ======
# Epoch 38 -> loss: 3104.033, reconstruction loss: 3010.909, KL divergence loss: -2862.492
# ====== val reconstruction loss: 61825.090 ======
# Epoch 39 -> loss: 3074.202, reconstruction loss: 2988.940, KL divergence loss: -2564.886
# ====== val reconstruction loss: 59475.586 ======
# Epoch 40 -> loss: 3088.935, reconstruction loss: 3001.221, KL divergence loss: -2751.298
# ====== val reconstruction loss: 61479.742 ======
# Epoch 41 -> loss: 3057.433, reconstruction loss: 2965.310, KL divergence loss: -2936.345
# ====== val reconstruction loss: 57649.500 ======
# Epoch 42 -> loss: 3089.394, reconstruction loss: 3000.127, KL divergence loss: -2869.658
# ====== val reconstruction loss: 64127.352 ======
# Epoch 43 -> loss: 3100.912, reconstruction loss: 3012.156, KL divergence loss: -2662.919
# ====== val reconstruction loss: 61308.961 ======
# Epoch 44 -> loss: 3063.382, reconstruction loss: 2976.932, KL divergence loss: -2667.519
# ====== val reconstruction loss: 58647.789 ======
# Epoch 45 -> loss: 3081.461, reconstruction loss: 2992.141, KL divergence loss: -2792.768
# ====== val reconstruction loss: 62110.359 ======
# Epoch 46 -> loss: 3100.870, reconstruction loss: 3010.749, KL divergence loss: -2775.005
# ====== val reconstruction loss: 62549.180 ======
# Epoch 47 -> loss: 3080.769, reconstruction loss: 2993.159, KL divergence loss: -2607.666
# ====== val reconstruction loss: 63905.953 ======
# Epoch 48 -> loss: 3091.056, reconstruction loss: 3001.911, KL divergence loss: -2829.714
# ====== val reconstruction loss: 65011.641 ======
# Epoch 49 -> loss: 3105.070, reconstruction loss: 3009.497, KL divergence loss: -2916.802
# ====== val reconstruction loss: 63710.918 ======
# Epoch 50 -> loss: 3091.198, reconstruction loss: 3000.762, KL divergence loss: -2778.658
# ====== val reconstruction loss: 57554.289 ======
# Epoch 51 -> loss: 3103.530, reconstruction loss: 3010.620, KL divergence loss: -2862.929
# ====== val reconstruction loss: 59288.246 ======
# Epoch 52 -> loss: 3091.805, reconstruction loss: 3003.772, KL divergence loss: -2752.498
# ====== val reconstruction loss: 60891.258 ======
# Epoch 53 -> loss: 3098.077, reconstruction loss: 3003.159, KL divergence loss: -2859.384
# ====== val reconstruction loss: 61314.465 ======
# Epoch 54 -> loss: 3093.078, reconstruction loss: 3006.012, KL divergence loss: -2684.479
# ====== val reconstruction loss: 58458.059 ======
# Epoch 55 -> loss: 3099.281, reconstruction loss: 3002.601, KL divergence loss: -2955.814
# ====== val reconstruction loss: 61268.586 ======
# Epoch 56 -> loss: 3096.935, reconstruction loss: 3006.728, KL divergence loss: -2784.392
# ====== val reconstruction loss: 62519.570 ======
# Epoch 57 -> loss: 3092.637, reconstruction loss: 3002.026, KL divergence loss: -2704.520
# ====== val reconstruction loss: 64159.371 ======
# Epoch 58 -> loss: 3077.228, reconstruction loss: 2988.058, KL divergence loss: -2793.021
# ====== val reconstruction loss: 58294.977 ======
# Epoch 59 -> loss: 3079.801, reconstruction loss: 2992.617, KL divergence loss: -2666.125
# ====== val reconstruction loss: 62213.750 ======
# Epoch 60 -> loss: 3099.577, reconstruction loss: 3010.104, KL divergence loss: -2846.857
# ====== val reconstruction loss: 60685.039 ======
# Epoch 61 -> loss: 3080.851, reconstruction loss: 2995.897, KL divergence loss: -2604.751
# ====== val reconstruction loss: 60609.344 ======
# Epoch 62 -> loss: 3106.488, reconstruction loss: 3014.286, KL divergence loss: -2741.302
# ====== val reconstruction loss: 59724.508 ======
# Epoch 63 -> loss: 3089.099, reconstruction loss: 3000.132, KL divergence loss: -2721.674
# ====== val reconstruction loss: 59969.461 ======
# Epoch 64 -> loss: 3101.096, reconstruction loss: 3010.452, KL divergence loss: -2790.214
# ====== val reconstruction loss: 61063.273 ======
# Epoch 65 -> loss: 3090.607, reconstruction loss: 3000.405, KL divergence loss: -2708.652
# ====== val reconstruction loss: 62368.051 ======
# Epoch 66 -> loss: 3096.876, reconstruction loss: 3001.312, KL divergence loss: -2988.405
# ====== val reconstruction loss: 60679.992 ======
# Epoch 67 -> loss: 3090.080, reconstruction loss: 3000.537, KL divergence loss: -2759.774
# ====== val reconstruction loss: 59533.789 ======
# Epoch 68 -> loss: 3082.128, reconstruction loss: 2993.197, KL divergence loss: -2770.318
# ====== val reconstruction loss: 60226.500 ======
# Epoch 69 -> loss: 3075.097, reconstruction loss: 2985.146, KL divergence loss: -2675.879
# ====== val reconstruction loss: 63224.676 ======
# Epoch 70 -> loss: 3069.500, reconstruction loss: 2983.006, KL divergence loss: -2670.963
# ====== val reconstruction loss: 60861.457 ======
# Epoch 71 -> loss: 3078.880, reconstruction loss: 2986.289, KL divergence loss: -2804.620
# ====== val reconstruction loss: 62138.570 ======
# Epoch 72 -> loss: 3127.588, reconstruction loss: 3031.896, KL divergence loss: -2877.121
# ====== val reconstruction loss: 61055.258 ======
# Epoch 73 -> loss: 3076.463, reconstruction loss: 2987.096, KL divergence loss: -2810.589
# ====== val reconstruction loss: 60647.984 ======
# Epoch 74 -> loss: 3081.942, reconstruction loss: 2992.350, KL divergence loss: -2772.273
# ====== val reconstruction loss: 59279.609 ======
# Epoch 75 -> loss: 3120.886, reconstruction loss: 3025.441, KL divergence loss: -2928.307
# ====== val reconstruction loss: 62959.137 ======
# Epoch 76 -> loss: 3119.576, reconstruction loss: 3023.598, KL divergence loss: -3226.990
# ====== val reconstruction loss: 62949.453 ======
# Epoch 77 -> loss: 3076.057, reconstruction loss: 2986.087, KL divergence loss: -2708.752
# ====== val reconstruction loss: 62505.273 ======
# Epoch 78 -> loss: 3069.966, reconstruction loss: 2982.248, KL divergence loss: -2733.959
# ====== val reconstruction loss: 62630.305 ======
# Epoch 79 -> loss: 3081.818, reconstruction loss: 2994.320, KL divergence loss: -2663.107
# ====== val reconstruction loss: 60048.398 ======
# Epoch 80 -> loss: 3111.430, reconstruction loss: 3015.323, KL divergence loss: -2878.267
# ====== val reconstruction loss: 64061.078 ======
# Epoch 81 -> loss: 3076.240, reconstruction loss: 2988.305, KL divergence loss: -2638.993
# ====== val reconstruction loss: 61205.273 ======
# Epoch 82 -> loss: 3124.236, reconstruction loss: 3035.539, KL divergence loss: -2846.210
# ====== val reconstruction loss: 60685.641 ======
# Epoch 83 -> loss: 3093.583, reconstruction loss: 2998.834, KL divergence loss: -2859.466
# ====== val reconstruction loss: 57856.844 ======
# Epoch 84 -> loss: 3083.021, reconstruction loss: 2994.761, KL divergence loss: -2901.336
# ====== val reconstruction loss: 61640.359 ======
# Epoch 85 -> loss: 3118.054, reconstruction loss: 3027.311, KL divergence loss: -2823.085
# ====== val reconstruction loss: 61564.047 ======
# Epoch 86 -> loss: 3082.221, reconstruction loss: 2992.598, KL divergence loss: -2778.318
# ====== val reconstruction loss: 62359.125 ======
# Epoch 87 -> loss: 3086.984, reconstruction loss: 3000.664, KL divergence loss: -2670.537
# ====== val reconstruction loss: 63257.109 ======
# Epoch 88 -> loss: 3086.268, reconstruction loss: 2992.391, KL divergence loss: -2866.552
# ====== val reconstruction loss: 59371.391 ======
# Epoch 89 -> loss: 3092.283, reconstruction loss: 3003.602, KL divergence loss: -2807.445
# ====== val reconstruction loss: 60019.680 ======
# Epoch 90 -> loss: 3101.032, reconstruction loss: 3010.503, KL divergence loss: -3021.123
# ====== val reconstruction loss: 57463.523 ======
# Epoch 91 -> loss: 3056.140, reconstruction loss: 2967.821, KL divergence loss: -2721.030
# ====== val reconstruction loss: 58450.375 ======
# Epoch 92 -> loss: 3094.424, reconstruction loss: 3005.978, KL divergence loss: -2767.523
# ====== val reconstruction loss: 58162.145 ======
# Epoch 93 -> loss: 3121.485, reconstruction loss: 3027.282, KL divergence loss: -2915.521
# ====== val reconstruction loss: 61091.922 ======
# Epoch 94 -> loss: 3096.502, reconstruction loss: 3007.571, KL divergence loss: -2727.816
# ====== val reconstruction loss: 59937.242 ======
# Epoch 95 -> loss: 3097.271, reconstruction loss: 3002.014, KL divergence loss: -4210.451
# ====== val reconstruction loss: 57231.297 ======
# Epoch 96 -> loss: 3065.989, reconstruction loss: 2978.426, KL divergence loss: -2648.342
# ====== val reconstruction loss: 60356.191 ======
# Epoch 97 -> loss: 3090.077, reconstruction loss: 2998.494, KL divergence loss: -2798.029
# ====== val reconstruction loss: 60321.004 ======
# Epoch 98 -> loss: 3068.510, reconstruction loss: 2976.998, KL divergence loss: -2815.530
# ====== val reconstruction loss: 61151.285 ======
# Epoch 99 -> loss: 3077.709, reconstruction loss: 2985.890, KL divergence loss: -2837.014
# ====== val reconstruction loss: 61570.531 ======
# Epoch 100 -> loss: 3111.139, reconstruction loss: 3016.239, KL divergence loss: -2939.417
# ====== val reconstruction loss: 62982.875 ======
# Epoch 101 -> loss: 3086.480, reconstruction loss: 2997.882, KL divergence loss: -2669.348
# ====== val reconstruction loss: 60670.867 ======
# Epoch 102 -> loss: 3101.375, reconstruction loss: 3005.000, KL divergence loss: -2947.297
# ====== val reconstruction loss: 59849.898 ======
# Epoch 103 -> loss: 3084.948, reconstruction loss: 2996.458, KL divergence loss: -2768.603
# ====== val reconstruction loss: 61117.715 ======
# Epoch 104 -> loss: 3087.454, reconstruction loss: 2986.975, KL divergence loss: -3410.547
# ====== val reconstruction loss: 58537.367 ======
# Epoch 105 -> loss: 3083.512, reconstruction loss: 2991.309, KL divergence loss: -2819.167
# ====== val reconstruction loss: 60030.516 ======
# Epoch 106 -> loss: 3069.008, reconstruction loss: 2982.533, KL divergence loss: -2609.065
# ====== val reconstruction loss: 62568.004 ======
# Epoch 107 -> loss: 3079.675, reconstruction loss: 2986.872, KL divergence loss: -2775.606
# ====== val reconstruction loss: 61859.609 ======
# Epoch 108 -> loss: 3086.188, reconstruction loss: 2997.342, KL divergence loss: -2776.238
# ====== val reconstruction loss: 61076.250 ======
# Epoch 109 -> loss: 3071.565, reconstruction loss: 2984.417, KL divergence loss: -2812.414
# ====== val reconstruction loss: 57283.102 ======
# Epoch 110 -> loss: 3080.256, reconstruction loss: 2992.009, KL divergence loss: -2756.925
# ====== val reconstruction loss: 59601.383 ======
# Epoch 111 -> loss: 3091.706, reconstruction loss: 2999.263, KL divergence loss: -2792.709
# ====== val reconstruction loss: 60764.062 ======
# Epoch 112 -> loss: 3088.111, reconstruction loss: 2994.125, KL divergence loss: -2875.606
# ====== val reconstruction loss: 62361.250 ======
# Epoch 113 -> loss: 3070.631, reconstruction loss: 2983.384, KL divergence loss: -2635.967
# ====== val reconstruction loss: 62798.707 ======
# Epoch 114 -> loss: 3121.620, reconstruction loss: 3033.093, KL divergence loss: -2624.820
# ====== val reconstruction loss: 65259.828 ======
# Epoch 115 -> loss: 3071.790, reconstruction loss: 2976.235, KL divergence loss: -2978.575
# ====== val reconstruction loss: 59523.758 ======
# Epoch 116 -> loss: 3082.289, reconstruction loss: 2992.392, KL divergence loss: -2683.741
# ====== val reconstruction loss: 62656.641 ======
# Epoch 117 -> loss: 3076.534, reconstruction loss: 2989.847, KL divergence loss: -2619.845
# ====== val reconstruction loss: 61370.527 ======
# Epoch 118 -> loss: 3086.109, reconstruction loss: 2999.210, KL divergence loss: -2608.823
# ====== val reconstruction loss: 61691.414 ======
# Epoch 119 -> loss: 3102.316, reconstruction loss: 3009.694, KL divergence loss: -2753.649
# ====== val reconstruction loss: 61585.906 ======
# Epoch 120 -> loss: 3095.029, reconstruction loss: 3002.141, KL divergence loss: -3144.250
# ====== val reconstruction loss: 63181.691 ======
# Epoch 121 -> loss: 3118.874, reconstruction loss: 3023.025, KL divergence loss: -2919.260
# ====== val reconstruction loss: 62457.070 ======
# Epoch 122 -> loss: 3084.063, reconstruction loss: 2992.948, KL divergence loss: -2735.199
# ====== val reconstruction loss: 60129.438 ======
# Epoch 123 -> loss: 3071.592, reconstruction loss: 2985.611, KL divergence loss: -2778.409
# ====== val reconstruction loss: 56430.504 ======
# Epoch 124 -> loss: 3101.286, reconstruction loss: 3007.012, KL divergence loss: -2934.285
# ====== val reconstruction loss: 59855.492 ======
# Epoch 125 -> loss: 3100.042, reconstruction loss: 3008.729, KL divergence loss: -2797.201
# ====== val reconstruction loss: 61191.871 ======
# Epoch 126 -> loss: 3071.343, reconstruction loss: 2983.263, KL divergence loss: -2794.905
# ====== val reconstruction loss: 61275.789 ======
# Epoch 127 -> loss: 3073.813, reconstruction loss: 2984.492, KL divergence loss: -2757.944
# ====== val reconstruction loss: 61682.613 ======
# Epoch 128 -> loss: 3092.957, reconstruction loss: 2999.164, KL divergence loss: -3830.140
# ====== val reconstruction loss: 56406.688 ======
# Epoch 129 -> loss: 3083.694, reconstruction loss: 2995.599, KL divergence loss: -2641.926
# ====== val reconstruction loss: 61522.773 ======
# Epoch 130 -> loss: 3105.941, reconstruction loss: 3018.181, KL divergence loss: -2634.274
# ====== val reconstruction loss: 62273.984 ======
# Epoch 131 -> loss: 3095.404, reconstruction loss: 3005.035, KL divergence loss: -2740.076
# ====== val reconstruction loss: 59916.102 ======
# Epoch 132 -> loss: 3112.345, reconstruction loss: 3019.966, KL divergence loss: -2820.045
# ====== val reconstruction loss: 62851.305 ======
# Epoch 133 -> loss: 3082.583, reconstruction loss: 2993.925, KL divergence loss: -2852.732
# ====== val reconstruction loss: 62004.336 ======
# Epoch 134 -> loss: 3098.252, reconstruction loss: 3006.340, KL divergence loss: -2872.895
# ====== val reconstruction loss: 56911.191 ======
# Epoch 135 -> loss: 3079.333, reconstruction loss: 2988.598, KL divergence loss: -2700.965
# ====== val reconstruction loss: 63236.664 ======
# Epoch 136 -> loss: 3075.767, reconstruction loss: 2986.140, KL divergence loss: -2931.732
# ====== val reconstruction loss: 58223.156 ======
# Epoch 137 -> loss: 3088.655, reconstruction loss: 2998.726, KL divergence loss: -2805.927
# ====== val reconstruction loss: 59648.773 ======
# Epoch 138 -> loss: 3077.325, reconstruction loss: 2989.122, KL divergence loss: -2695.810
# ====== val reconstruction loss: 63754.855 ======
# Epoch 139 -> loss: 3081.488, reconstruction loss: 2989.523, KL divergence loss: -2911.804
# ====== val reconstruction loss: 63416.855 ======
# Epoch 140 -> loss: 3097.006, reconstruction loss: 3007.650, KL divergence loss: -3065.950
# ====== val reconstruction loss: 55462.359 ======
# Epoch 141 -> loss: 3089.529, reconstruction loss: 2998.945, KL divergence loss: -2908.831
# ====== val reconstruction loss: 60807.641 ======
# Epoch 142 -> loss: 3121.049, reconstruction loss: 3016.887, KL divergence loss: -4750.320
# ====== val reconstruction loss: 56592.227 ======
# Epoch 143 -> loss: 3095.799, reconstruction loss: 3009.385, KL divergence loss: -2670.661
# ====== val reconstruction loss: 58559.926 ======
# Epoch 144 -> loss: 3081.347, reconstruction loss: 2994.334, KL divergence loss: -2590.280
# ====== val reconstruction loss: 62911.227 ======
# Epoch 145 -> loss: 3084.261, reconstruction loss: 2989.201, KL divergence loss: -2911.729
# ====== val reconstruction loss: 60393.758 ======
# Epoch 146 -> loss: 3080.459, reconstruction loss: 2991.588, KL divergence loss: -2718.876
# ====== val reconstruction loss: 60841.516 ======
# Epoch 147 -> loss: 3085.885, reconstruction loss: 2995.646, KL divergence loss: -2738.762
# ====== val reconstruction loss: 62400.465 ======
# Epoch 148 -> loss: 3048.256, reconstruction loss: 2960.584, KL divergence loss: -2751.717
# ====== val reconstruction loss: 59624.594 ======
# Epoch 149 -> loss: 3096.728, reconstruction loss: 3005.536, KL divergence loss: -2977.347
# ====== val reconstruction loss: 56589.703 ======
# Epoch 150 -> loss: 3086.153, reconstruction loss: 2997.347, KL divergence loss: -2783.392
# ====== val reconstruction loss: 59174.016 ======
# Epoch 151 -> loss: 3107.771, reconstruction loss: 3016.899, KL divergence loss: -2778.411
# ====== val reconstruction loss: 59638.914 ======
# Epoch 152 -> loss: 3068.745, reconstruction loss: 2981.713, KL divergence loss: -2629.006
# ====== val reconstruction loss: 59967.469 ======
# Epoch 153 -> loss: 3124.004, reconstruction loss: 3029.608, KL divergence loss: -2940.273
# ====== val reconstruction loss: 65473.184 ======
# Epoch 154 -> loss: 3099.994, reconstruction loss: 3012.723, KL divergence loss: -2736.419
# ====== val reconstruction loss: 58771.562 ======
# Epoch 155 -> loss: 3079.617, reconstruction loss: 2987.706, KL divergence loss: -2821.675
# ====== val reconstruction loss: 59041.848 ======
# Epoch 156 -> loss: 3073.172, reconstruction loss: 2985.161, KL divergence loss: -2824.466
# ====== val reconstruction loss: 60353.094 ======
# Epoch 157 -> loss: 3103.779, reconstruction loss: 3011.120, KL divergence loss: -2833.773
# ====== val reconstruction loss: 58617.352 ======
# Epoch 158 -> loss: 3064.271, reconstruction loss: 2974.134, KL divergence loss: -2684.661
# ====== val reconstruction loss: 60552.234 ======
# Epoch 159 -> loss: 3095.515, reconstruction loss: 3008.362, KL divergence loss: -2603.810
# ====== val reconstruction loss: 62658.406 ======
# Epoch 160 -> loss: 3085.889, reconstruction loss: 2999.086, KL divergence loss: -2587.552
# ====== val reconstruction loss: 62578.500 ======
# Epoch 161 -> loss: 3101.349, reconstruction loss: 3006.907, KL divergence loss: -2877.493
# ====== val reconstruction loss: 62191.527 ======
# Epoch 162 -> loss: 3060.959, reconstruction loss: 2972.697, KL divergence loss: -2715.423
# ====== val reconstruction loss: 57176.730 ======
# Epoch 163 -> loss: 3081.065, reconstruction loss: 2995.300, KL divergence loss: -2634.870
# ====== val reconstruction loss: 60425.109 ======
# Epoch 164 -> loss: 3054.089, reconstruction loss: 2966.806, KL divergence loss: -2601.387
# ====== val reconstruction loss: 60984.305 ======
# Epoch 165 -> loss: 3080.458, reconstruction loss: 2994.439, KL divergence loss: -2635.163
# ====== val reconstruction loss: 60374.570 ======
# Epoch 166 -> loss: 3084.738, reconstruction loss: 2994.836, KL divergence loss: -2788.920
# ====== val reconstruction loss: 60372.719 ======
# Epoch 167 -> loss: 3064.302, reconstruction loss: 2976.701, KL divergence loss: -2628.238
# ====== val reconstruction loss: 61633.875 ======
# Epoch 168 -> loss: 3100.456, reconstruction loss: 3014.083, KL divergence loss: -2674.578
# ====== val reconstruction loss: 59347.445 ======
# Epoch 169 -> loss: 3099.078, reconstruction loss: 3010.854, KL divergence loss: -2727.387
# ====== val reconstruction loss: 58168.613 ======
# Epoch 170 -> loss: 3073.586, reconstruction loss: 2984.006, KL divergence loss: -2662.266
# ====== val reconstruction loss: 63178.703 ======
# Epoch 171 -> loss: 3142.653, reconstruction loss: 3050.072, KL divergence loss: -3135.318
# ====== val reconstruction loss: 61720.043 ======
# Epoch 172 -> loss: 3067.321, reconstruction loss: 2980.241, KL divergence loss: -2688.326
# ====== val reconstruction loss: 60746.266 ======
# Epoch 173 -> loss: 3077.978, reconstruction loss: 2983.905, KL divergence loss: -2980.851
# ====== val reconstruction loss: 60300.223 ======
# Epoch 174 -> loss: 3105.829, reconstruction loss: 3013.893, KL divergence loss: -2872.881
# ====== val reconstruction loss: 61204.281 ======
# Epoch 175 -> loss: 3075.347, reconstruction loss: 2982.393, KL divergence loss: -3091.716
# ====== val reconstruction loss: 56813.016 ======
# Epoch 176 -> loss: 3099.884, reconstruction loss: 3009.136, KL divergence loss: -2761.938
# ====== val reconstruction loss: 63294.305 ======
# Epoch 177 -> loss: 3076.638, reconstruction loss: 2986.446, KL divergence loss: -2823.905
# ====== val reconstruction loss: 58708.148 ======
# Epoch 178 -> loss: 3082.708, reconstruction loss: 2988.975, KL divergence loss: -2935.045
# ====== val reconstruction loss: 59713.121 ======
# Epoch 179 -> loss: 3098.164, reconstruction loss: 3009.210, KL divergence loss: -2657.954
# ====== val reconstruction loss: 61808.953 ======
# Epoch 180 -> loss: 3097.502, reconstruction loss: 3011.406, KL divergence loss: -2656.007
# ====== val reconstruction loss: 61423.336 ======
# Epoch 181 -> loss: 3081.809, reconstruction loss: 2992.008, KL divergence loss: -2730.904
# ====== val reconstruction loss: 62218.664 ======
# Epoch 182 -> loss: 3119.223, reconstruction loss: 3026.913, KL divergence loss: -2820.309
# ====== val reconstruction loss: 64087.039 ======
# Epoch 183 -> loss: 3084.570, reconstruction loss: 2996.174, KL divergence loss: -2901.605
# ====== val reconstruction loss: 64423.676 ======
# Epoch 184 -> loss: 3089.192, reconstruction loss: 3000.901, KL divergence loss: -2902.230
# ====== val reconstruction loss: 61272.750 ======
# Epoch 185 -> loss: 3108.901, reconstruction loss: 3019.078, KL divergence loss: -2795.249
# ====== val reconstruction loss: 62571.797 ======
# Epoch 186 -> loss: 3092.812, reconstruction loss: 3000.305, KL divergence loss: -2918.885
# ====== val reconstruction loss: 61525.184 ======
# Epoch 187 -> loss: 3110.893, reconstruction loss: 3015.921, KL divergence loss: -3150.532
# ====== val reconstruction loss: 58111.180 ======
# Epoch 188 -> loss: 3090.311, reconstruction loss: 3003.488, KL divergence loss: -2650.981
# ====== val reconstruction loss: 57972.266 ======
# Epoch 189 -> loss: 3079.963, reconstruction loss: 2989.824, KL divergence loss: -2822.202
# ====== val reconstruction loss: 59198.711 ======
# Epoch 190 -> loss: 3091.435, reconstruction loss: 3000.016, KL divergence loss: -2853.583
# ====== val reconstruction loss: 63035.137 ======
# Epoch 191 -> loss: 3085.721, reconstruction loss: 2998.440, KL divergence loss: -2737.338
# ====== val reconstruction loss: 58317.320 ======
# Epoch 192 -> loss: 3100.499, reconstruction loss: 3010.115, KL divergence loss: -2801.212
# ====== val reconstruction loss: 59478.551 ======
# Epoch 193 -> loss: 3101.531, reconstruction loss: 3011.759, KL divergence loss: -2893.320
# ====== val reconstruction loss: 56583.344 ======
# Epoch 194 -> loss: 3088.554, reconstruction loss: 2998.299, KL divergence loss: -2759.137
# ====== val reconstruction loss: 60177.555 ======
# Epoch 195 -> loss: 3084.586, reconstruction loss: 2995.501, KL divergence loss: -2709.368
# ====== val reconstruction loss: 61402.664 ======
# Epoch 196 -> loss: 3106.127, reconstruction loss: 3010.172, KL divergence loss: -2884.211
# ====== val reconstruction loss: 61815.020 ======
# Epoch 197 -> loss: 3087.170, reconstruction loss: 2998.144, KL divergence loss: -2854.039
# ====== val reconstruction loss: 59946.164 ======
# Epoch 198 -> loss: 3078.119, reconstruction loss: 2988.075, KL divergence loss: -2949.562
# ====== val reconstruction loss: 62049.102 ======
# Epoch 199 -> loss: 3085.487, reconstruction loss: 2998.651, KL divergence loss: -2725.997
# ====== val reconstruction loss: 60147.969 ======

# %%
# Testing
model.eval()
val_losses, val_bces, val_klds = 0, 0, 0
for idx, (input_imgs, output_imgs) in enumerate(testloader): 
    input_imgs = input_imgs.to(device)
    output_imgs = output_imgs.to(device)

    recon_images = model.generate(input_imgs)

    recon_images = recon_images.cpu().detach().numpy()
    output_imgs = output_imgs.cpu().detach().numpy()


    fig, axes = plt.subplots(1,2)
    
    ref_img = stitch_imgs(output_imgs)
    recon_img = stitch_imgs(recon_images)
    
    axes[0].imshow(ref_img)
    axes[1].imshow(recon_img)
    
    print(f'AUC score: {roc_auc_score(ref_img.flatten(), recon_img.flatten())}')
    
    
    plt.show()
# Out:
# AUC score: 0.5190194546579112
# AUC score: 0.7476791822860468
# AUC score: 0.5832978457495371

# %%
torch.save(model, './')

# %%
# mapping = {
#     0: 'pixel_id', 
#     1: 'pixel_id.1', 
#     2: 'Road_Dist', 
#     3: 'Elec_Dist', 
#     4: 'Cultivated_Prop', 
#     5: 'Elev', 
#     6: 'time_Normal', 
#     7: 'aet__count_above_mean_Normal', 
#     8: 'aet__count_below_mean_Normal', 
#     9: 'aet__first_location_of_maximum_Normal', 
#     10: 'aet__last_location_of_maximum_Normal', 
#     11: 'aet__longest_strike_above_mean_Normal', 
#     12: 'aet__longest_strike_below_mean_Normal', 
#     13: 'aet__maximum_Normal', 
#     14: 'aet__mean_Normal', 
#     15: 'aet__minimum_Normal', 
#     16: 'aet__quantile__q_0.1_Normal', 
#     17: 'aet__quantile__q_0.5_Normal', 
#     18: 'aet__quantile__q_0.9_Normal', 
#     19: 'aet__skewness_Normal', 
#     20: 'aet__standard_deviation_Normal', 
#     21: 'cwd__count_above_mean_Normal', 
#     22: 'cwd__count_below_mean_Normal', 
#     23: 'cwd__first_location_of_maximum_Normal', 
#     24: 'cwd__last_location_of_maximum_Normal', 
#     25: 'cwd__longest_strike_above_mean_Normal', 
#     26: 'cwd__longest_strike_below_mean_Normal', 
#     27: 'cwd__maximum_Normal', 
#     28: 'cwd__mean_Normal', 
#     29: 'cwd__minimum_Normal', 
#     30: 'cwd__quantile__q_0.1_Normal', 
#     31: 'cwd__quantile__q_0.5_Normal', 
#     32: 'cwd__quantile__q_0.9_Normal', 
#     33: 'cwd__skewness_Normal', 
#     34: 'cwd__standard_deviation_Normal', 
#     35: 'pck__count_above_mean_Normal', 
#     36: 'pck__count_below_mean_Normal', 
#     37: 'pck__first_location_of_maximum_Normal', 
#     38: 'pck__last_location_of_maximum_Normal', 
#     39: 'pck__longest_strike_above_mean_Normal', 
#     40: 'pck__longest_strike_below_mean_Normal', 
#     41: 'pck__maximum_Normal', 
#     42: 'pck__mean_Normal', 
#     43: 'pck__minimum_Normal', 
#     44: 'pck__quantile__q_0.1_Normal', 
#     45: 'pck__quantile__q_0.5_Normal', 
#     46: 'pck__quantile__q_0.9_Normal', 
#     47: 'pck__skewness_Normal', 
#     48: 'pck__standard_deviation_Normal', 
#     49: 'time', 
#     50: 'aet__mean_ThreeYear_Dev', 
#     51: 'cwd__mean_ThreeYear_Dev', 
#     52: 'Mean_Housing_Dens_25km', 
#     53: 'FFWI', 
#     54: 'FFWI_UCLA', 
#     55: 'time_since_fire'}
